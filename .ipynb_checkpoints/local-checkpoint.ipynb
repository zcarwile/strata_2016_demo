# %%
import nltk
import pandas as pd

import geograpy

# %% [markdown]
# ### Named Entity Recognition

# %%
words_df = pd.DataFrame(
    columns=['year','president','words'],
)
words_df[['year', 'words']] = words_df[['year', 'words']].astype(int)

countries_df = pd.DataFrame(
    columns=['year','country','region','mentions']
)
countries_df[['year', 'mentions']] = countries_df[['year', 'mentions']].astype(int)

DIR = "/Users/zcarwile/nltk_data/corpora/state_union/"

country_region_map = country_region_map = {
    'Canada': 'North America', 
    'Cambodia': 'Asia', 
    'Ethiopia': 'Africa', 
    'Argentina': 'South America', 
    'Bahrain': 'Middle East', 
    'Saudi Arabia': 'Middle East', 
    'Guatemala': 'North America', 
    'Bosnia and Herzegovina': 'Europe', 
    'Russian Federation': 'Europe', 
    'Germany': 'Europe', 
    'Spain': 'Europe', 
    'Netherlands': 'Europe', 
    'Christmas Island': 'Other', 
    'New Zealand': 'Other', 
    'Yemen': 'Middle Est', 
    'Pakistan': 'Middle East', 
    'Viet Nam': 'Asia', 
    'Saint Vincent and the Grenadines': 'Other', 
    'Kenya': 'Africa', 
    'Turkey': 'Europe', 
    'Afghanistan': 'Middle East', 
    'Czech Republic': 'Europe', 
    'Solomon Islands': 'Other', 
    'India': 'Asia', 
    'France': 'Europe', 
    'Somalia': 'Africa', 
    'Peru': 'South America', 
    'Norway': 'Europe', 
    'Singapore': 'Asia', 
    'Iran, Islamic Republic of': 'Middle East', 
    'China': 'Asia', 
    'Micronesia, Federated States of': 'Other', 
    'Ukraine': 'Europe', 
    'Finland': 'Europe', 
    'Indonesia': 'Asia', 
    'Central African Republic': 'Africa', 
    'United States': 'North America', 
    'Sweden': 'Europe', 
    'Belarus': 'Europe', 
    'Bulgaria': 'Europe', 
    'Romania': 'Europe', 
    'Angola': 'Africa', 
    'French Southern Territories': 'Other', 
    'Portugal': 'Europe', 
    'South Africa': 'Africa', 
    'Cyprus': 'Middle East', 
    'Venezuela, Bolivarian Republic of': 'South America', 
    'Austria': 'Europe', 
    'Japan': 'Asia', 
    'Brazil': 'South America', 
    'Kuwait': 'Middle East', 
    'Panama': 'North America', 
    'Korea, Republic of': 'Asia', 
    'Costa Rica': 'North America', 
    'Bahamas': 'North America', 
    'Ireland': 'Europe', 
    'Nigeria': 'Africa', 
    'Australia': 'Other', 
    'Chile': 'South America', 
    'Puerto Rico': 'North America', 
    'Belgium': 'Europe', 
    'Thailand': 'Asia', 
    'Haiti': 'North America', 
    'Iraq': 'Middle East', 
    'Georgia': 'Europe', 
    'Denmark': 'Europe', 
    'Poland': 'Europe', 
    'Morocco': 'Africa', 
    'Namibia': 'Africa', 
    'Switzerland': 'Europe', 
    'Grenada': 'Other', 
    'Tanzania, United Republic of': 'Africa', 
    'Uruguay': 'South America', 
    'Lebanon': 'Middle East', 
    'Uzbekistan': 'Asia', 
    'Colombia': 'South America', 
    'Nicaragua': 'North America', 
    'Italy': 'Europe', 
    'Israel': 'Middle East', 
    'Iceland': 'Europe', 
    'Zimbabwe': 'Africa', 
    'Jordan': 'Middle East', 
    'Philippines': 'Asia', 
    'British Indian Ocean Territory': 'Other', 
    "Korea, Democratic People's Republic of": 'Asia', 
    'Trinidad and Tobago': 'Other', 
    'Hungary': 'Europe', 
    'Mexico': 'North America', 
    'Egypt': 'Middle East', 
    'Cuba': 'North America', 
    'United Kingdom': 'Europe', 
    'Antarctica': 'Other', 
    'Congo': 'Africa', 
    'Greece': 'Europe'
}

# %%
i = 0
j = 0
for id in nltk.corpus.state_union.fileids():
    
    # add word count to DF
    year = id[0:4]
    year_int = int(year)
    president = id.split("-")[1].split(".")[0]
    words = len(nltk.corpus.state_union.words(id))
    words_df.loc[i] = [year_int,president,words]
    
    # extract places and add to DF
    with open(DIR + id, 'r') as myfile:
        text=myfile.read().replace('\n', '') 
    places = geograpy.get_place_context(text=unicode(text,encoding='utf-8', errors='ignore'))
    for country in places.country_mentions:
        region = country_region_map.get(str(country[0]))
        countries_df.loc[j] = [year_int,country[0],region,country[1]]
        j = j + 1
        
    
    i = i + 1
    
    # Execution control
    if year[3] in ['0','5']:
        print(year)
    #if i > 3:
    #    break
# Out:
# 1945
# 1950
# 1955
# 1960
# 1965
# 1965
# 1970
# 1975
# 1980
# 1985
# 1990
# 1995
# 2000
# 2005

# %% [markdown]
# ### Document statistics

# %%
words_df[words_df['year'] == 1991]
# Out:
#     year president  words
# 60  2002    GWBush   4689
# 61  2003    GWBush   6241
# 62  2004    GWBush   6240
# 63  2005    GWBush   6053
# 64  2006    GWBush   6515

# %%
countries_df[countries_df['year'] == 1991]
# Out:
#      year                       country         region  mentions
# 469  1991                          Iraq    Middle East         6
# 470  1991                        Kuwait    Middle East         2
# 471  1991                       Bahrain    Middle East         1
# 472  1991                        Israel    Middle East         1
# 473  1991   French Southern Territories          Other         1
# 474  1991                United Kingdom         Europe         1
# 475  1991                 United States  North America         1
# 476  1991                         Spain         Europe         1
# 477  1991                         India           Asia         1
# 478  1991                    Costa Rica  North America         1
# 479  1991                          Iraq    Middle East         8
# 480  1991                        Israel    Middle East         4
# 481  1991                        Kuwait    Middle East         4
# 482  1991                       Lebanon    Middle East         2
# 483  1991                   Afghanistan    Middle East         1
# 484  1991                       Georgia         Europe         1
# 485  1991  Tanzania, United Republic of         Africa         1
# 486  1991                         Egypt    Middle East         1
# 487  1991      Central African Republic         Africa         1
# 488  1991                        France         Europe         1
# 489  1991                United Kingdom         Europe         1
# 490  1991              Christmas Island          Other         1
# 491  1991                 United States  North America         1

# %%
whole_df = words_df.merge(countries_df, on='year', how='left')
whole_df[whole_df['year'] == 1991]
# Out:
#      year president  words                       country         region  \
# 502  1991      Bush   4661                          Iraq    Middle East
# 503  1991      Bush   4661                        Kuwait    Middle East
# 504  1991      Bush   4661                       Bahrain    Middle East
# 505  1991      Bush   4661                        Israel    Middle East
# 506  1991      Bush   4661   French Southern Territories          Other
# 507  1991      Bush   4661                United Kingdom         Europe
# 508  1991      Bush   4661                 United States  North America
# 509  1991      Bush   4661                         Spain         Europe
# 510  1991      Bush   4661                         India           Asia
# 511  1991      Bush   4661                    Costa Rica  North America
# 512  1991      Bush   4661                          Iraq    Middle East
# 513  1991      Bush   4661                        Israel    Middle East
# 514  1991      Bush   4661                        Kuwait    Middle East
# 515  1991      Bush   4661                       Lebanon    Middle East
# 516  1991      Bush   4661                   Afghanistan    Middle East
# 517  1991      Bush   4661                       Georgia         Europe
# 518  1991      Bush   4661  Tanzania, United Republic of         Africa
# 519  1991      Bush   4661                         Egypt    Middle East
# 520  1991      Bush   4661      Central African Republic         Africa
# 521  1991      Bush   4661                        France         Europe
# 522  1991      Bush   4661                United Kingdom         Europe
# 523  1991      Bush   4661              Christmas Island          Other
# 524  1991      Bush   4661                 United States  North America
# 525  1991      Bush   3357                          Iraq    Middle East
# 526  1991      Bush   3357                        Kuwait    Middle East
# 527  1991      Bush   3357                       Bahrain    Middle East
# 528  1991      Bush   3357                        Israel    Middle East
# 529  1991      Bush   3357   French Southern Territories          Other
# 530  1991      Bush   3357                United Kingdom         Europe
# 531  1991      Bush   3357                 United States  North America
# 532  1991      Bush   3357                         Spain         Europe
# 533  1991      Bush   3357                         India           Asia
# 534  1991      Bush   3357                    Costa Rica  North America
# 535  1991      Bush   3357                          Iraq    Middle East
# 536  1991      Bush   3357                        Israel    Middle East
# 537  1991      Bush   3357                        Kuwait    Middle East
# 538  1991      Bush   3357                       Lebanon    Middle East
# 539  1991      Bush   3357                   Afghanistan    Middle East
# 540  1991      Bush   3357                       Georgia         Europe
# 541  1991      Bush   3357  Tanzania, United Republic of         Africa
# 542  1991      Bush   3357                         Egypt    Middle East
# 543  1991      Bush   3357      Central African Republic         Africa
# 544  1991      Bush   3357                        France         Europe
# 545  1991      Bush   3357                United Kingdom         Europe
# 546  1991      Bush   3357              Christmas Island          Other
# 547  1991      Bush   3357                 United States  North America
#
#      mentions
# 502         6
# 503         2
# 504         1
# 505         1
# 506         1
# 507         1
# 508         1
# 509         1
# 510         1
# 511         1
# 512         8
# 513         4
# 514         4
# 515         2
# 516         1
# 517         1
# 518         1
# 519         1
# 520         1
# 521         1
# 522         1
# 523         1
# 524         1
# 525         6
# 526         2
# 527         1
# 528         1
# 529         1
# 530         1
# 531         1
# 532         1
# 533         1
# 534         1
# 535         8
# 536         4
# 537         4
# 538         2
# 539         1
# 540         1
# 541         1
# 542         1
# 543         1
# 544         1
# 545         1
# 546         1
# 547         1

# %%
from bokeh.charts import Bar
from bokeh.plotting import ColumnDataSource
from bokeh.io import output_notebook, show
from bokeh.models import HoverTool
output_notebook()

TOOLS = 'box_zoom,box_select,hover,resize,reset'

p = Bar(words_df, label='year',values='words', color='president', tools=TOOLS, width=1000, height=400, ylabel="Words")
hover = p.select(dict(type=HoverTool))
hover.tooltips = [
                    ("year", "@year"),
                    ("president", "@president")
                 ]

show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d991993d-fc4b-4e76-8e61-308f445c3b0f">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="c0935673-22d4-4901-bb22-344b1522192d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0935673-22d4-4901-bb22-344b1522192d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0935673-22d4-4901-bb22-344b1522192d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"fb8a0fcf-cb8a-4f2b-b0a0-934d487ee454":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"president":"Johnson","year":1965}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[9158.0],"line_alpha":[1.0],"line_color":["white"],"president":["Johnson"],"width":[0.8],"x":["1965"],"y":[4579.0],"year":[1965]}},"id":"35fde7f0-0dbe-46a0-89b2-976cf26eb45b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3073f3f2-be5a-4c14-a2ab-07b8aa85cc1a","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"president":"Clinton","year":1996}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[7277.0],"line_alpha":[1.0],"line_color":["white"],"president":["Clinton"],"width":[0.8],"x":["1996"],"y":[3638.5],"year":[1996]}},"id":"627d724c-d399-4e76-8555-ccdc839a9147","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"president":"Clinton","year":2000}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[10640.0],"line_alpha":[1.0],"line_color":["white"],"president":["Clinton"],"width":[0.8],"x":["2000"],"y":[5320.0],"year":[2000]}},"id":"2e1bc5ad-a9fd-4a69-aca7-a5dbdb7475ff","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8bdd4aeb-5d73-45ce-b2c4-cd3213a8f9af","type":"Rect"},{"attributes":{"data_source":{"id":"afbf9ad6-e42a-463e-9b62-8391b376e55c","type":"ColumnDataSource"},"glyph":{"id":"972591a1-5c1d-4500-9750-254408440bd7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"90275089-be08-4b82-bde8-2a229c44655e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4b74eabb-20b2-4d24-aa50-5bf337e7c92e","type":"Rect"},{"attributes":{"data_source":{"id":"389e82d0-074e-4670-883f-1890f5084407","type":"ColumnDataSource"},"glyph":{"id":"8f34b2a5-6dfd-44f2-8514-8480f8fb4d06","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9e285f3a-918a-4674-ace3-43626bf2d739","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"2e1bc5ad-a9fd-4a69-aca7-a5dbdb7475ff","type":"ColumnDataSource"},"glyph":{"id":"eb7d57a4-54a4-4599-be42-0edc207cf460","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5bb6f1a8-d139-4027-a7c9-d9c02862157a","type":"GlyphRenderer"},{"attributes":{"axis_label":"Year","formatter":{"id":"f61a8209-e495-471b-9c6a-5c99346f1a8f","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"2362d9c9-273d-4348-9b7a-ba2ef6c035a4","subtype":"Chart","type":"Plot"},"ticker":{"id":"29ecab6d-fa5f-436f-8244-ccbd67ca740b","type":"CategoricalTicker"}},"id":"24729af3-3f59-4992-8da0-7b9e0cdbe20d","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8f34b2a5-6dfd-44f2-8514-8480f8fb4d06","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","he ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %%
p = Bar(countries_df, label='year', values='mentions', stack='region', agg='sum', legend='top_left', 
        tools=TOOLS, width=1000, height=400, ylabel="Country Mentions")

hover = p.select(dict(type=HoverTool))
hover.tooltips = [
                    ("year", "@year"),
                    ("region", "@region"),
                    ("president","$president")
                 ]

show(p)
# Out:
#     <div class="plotdiv" id="95dda673-e601-4489-86d9-90bdae670dc4"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("95dda673-e601-4489-86d9-90bdae670dc4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '95dda673-e601-4489-86d9-90bdae670dc4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"efcef2b4-3ab9-420c-9564-05e5c9359502":{"roots":{"references":[{"attributes":{"data_source":{"id":"d3fa26a2-febc-47d8-8c7a-4b213f50c74b","type":"ColumnDataSource"},"glyph":{"id":"c9430f60-6c1c-4cd0-868a-9420d341e65b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c82b9ad2-0ec8-4c42-ade6-84a2c1f051fd","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"region":"North America","year":1971}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[2.0],"line_alpha":[1.0],"line_color":["white"],"region":["North America"],"width":[0.8],"x":["1971"],"y":[3.0],"year":[1971]}},"id":"48863873-73d8-4ed3-ad33-20e2b7bef8d9","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5c332d9f-2f6d-4424-9e2d-289d4acda6f5","type":"ColumnDataSource"},"glyph":{"id":"c47f0a80-4c6b-4387-8479-4d9a19ca4608","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"db8af701-43b1-43c4-a35b-494973cfa0ab","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"region":"Europe","year":1972}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[2.0],"line_alpha":[1.0],"line_color":["white"],"region":["Europe"],"width":[0.8],"x":["1972"],"y":[8.0],"year":[1972]}},"id":"51d3de01-a746-41e6-ac20-7cb2e14547b2","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"0e31f15b-aef7-4daf-b70b-6aa9c1e1a060","type":"ColumnDataSource"},"glyph":{"id":"9fc1796c-a673-4e33-81f3-5b9a3e0f75ff","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cc88ecc2-ca1d-4eec-aae1-f743d994c185","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"aba5d37d-4346-4d8d-83ae-fa893318a3ab","type":"ColumnDataSource"},"glyph":{"id":"43db67ef-7655-4eb1-83a0-324b25a4bb50","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0f29c09a-f269-4069-8da6-7bd756db38ec","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"region":"North America","year":1977}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[2.0],"line_alpha":[1.0],"line_color":["white"],"region":["North America"],"width":[0.8],"x":["1977"],"y":[6.0],"year":[1977]}},"id":"61882deb-6cbd-4caa-ba87-a634b5556f32","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c8ec8c86-f569-4b55-a503-91a0ad0e6285","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1272d93-3529-43c4-aca0-69c0251539c3","type":"Rect"},{"attributes":{"data_source":{"id":"92a6babc-3cc4-4650-a3e0-ec9f88fa5f1d","type":"ColumnDataSource"},"glyph":{"id":"919b0322-dafd-4085-addb-30d55fc116c4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a6dd063a-7cd6-422d-9426-52a99d23d750","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"region":"North America","year":1989}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[5.0],"line_alpha":[1.0],"line_color":["white"],"region":["North America"],"width":[0.8],"x":["1989"],"y":[2.5],"year":[1989]}},"id":"12885cc4-b9db-4a88-8488-5d9a849ca131","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"co ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[24]</strong>&gt;</code></p>

# %% [markdown]
# ### Attic

# %%
countries_df.loc[whole_df['year'] == 1991]
# Out:
#      year                                 country         region  mentions
# 502  1993                               Argentina  South America         1
# 503  1994                      Russian Federation         Europe         4
# 504  1994                                 Ukraine         Europe         2
# 505  1994                                  Canada  North America         1
# 506  1994                                 Belarus         Europe         1
# 507  1994                          United Kingdom         Europe         1
# 508  1994                                   China           Asia         1
# 509  1994                  Bosnia and Herzegovina         Europe         1
# 510  1994                                   Haiti  North America         1
# 511  1994                                 Somalia         Africa         1
# 512  1994                           United States  North America         1
# 513  1994                             Puerto Rico  North America         1
# 514  1994                               Argentina  South America         1
# 515  1994                             Philippines           Asia         1
# 516  1994                                 Hungary         Europe         1
# 517  1994                             New Zealand          Other         1
# 518  1994                     Trinidad and Tobago          Other         1
# 519  1994                                 Uruguay  South America         1
# 520  1994                                  Brazil  South America         1
# 521  1995                                  Mexico  North America         3
# 522  1995                                   Haiti  North America         3
# 523  1995                                  Israel    Middle East         2
# 524  1995             French Southern Territories          Other         1
# 525  1995                                  Kuwait    Middle East         1
# 526  1995                          United Kingdom         Europe         1
# 527  1995                           United States  North America         1
# 528  1995                             Philippines           Asia         1
# 529  1995                             New Zealand          Other         1
# 530  1995                                  Canada  North America         1
# 531  1995                               Australia          Other         1
# 532  1995                               Argentina  South America         1
# 533  1995                     Trinidad and Tobago          Other         1
# 534  1995                                  Brazil  South America         1
# 535  1996                  Bosnia and Herzegovina         Europe         2
# 536  1996                                Viet Nam           Asia         1
# 537  1996  Korea, Democratic People's Republic of           Asia         1
# 538  1996                      Russian Federation         Europe         1
# 539  1996                                   Japan           Asia         1
# 540  1996                                   Haiti  North America         1
# 541  1996                          United Kingdom         Europe         1
# 542  1996                           United States  North America         1
# 543  1996                                  Canada  North America         1
# 544  1996                                 Hungary         Europe         1
# 545  1996        Saint Vincent and the Grenadines          Other         1
# 546  1996                     Trinidad and Tobago          Other         1
# 547  1996                                 Uruguay  South America         1

# %%
nltk.corpus.state_union.words()

# %%
FILE='2005-GWBush.txt'
with open(DIR + FILE, 'r') as myfile:
    text=myfile.read().replace('\n', '')
print(text)
